# %%
import pickle as pkl
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set_style('white')
palette = ["#1b4079", "#C6DDF0", "#048A81", "#B9E28C", "#8C2155", "#AF7595", "#E6480F", "#FA9500"]
sns.set(palette = palette, font_scale=2.0, style="white", rc={"lines.linewidth": 4.0})

# %%
stn_names, stn_lonlat, full_data = pkl.load(open("./wind_data.p", 'rb'))

# %%
def ECDF(sample_pxs, true_px):    
    return (torch.sum(sample_pxs < true_px, 0)/sample_pxs.shape[0])
 
def Calibration(pcts, percentile=0.95):
    in_band = np.where((pcts < percentile))[0].shape[0]
    return in_band/pcts.shape[0]

def GetCalibration(model, ema=True, k=100, theta=0.0, horizon=np.arange(75,100), 
                   logger=[], exp=True):
    
    ntime = full_data[0].shape[0]
    ntrain = 400
    n_test_times = 20
    ntest = 100
    test_idxs = torch.arange(ntrain, ntime-ntest, 
                             int((ntime-ntest-ntrain)/n_test_times))
    
    stns = list(stn_names.keys())
#     pcts = torch.zeros(len(stns), len(test_idxs), horizon.shape[0])    
    pcts = torch.tensor([])
    for stn_save_idx, stn_idx in enumerate(stns):
        for test_save_idx, test_idx in enumerate(test_idxs):

            fpath = "./saved-outputs/stn" + str(stn_idx) + "/"
            fname = model + "_"
            if model == 'volt':
                if ema:
                    fname += "ema" + str(k) + "_"
                fname += "theta" + str(theta) + "_"
            if model == 'matern':
                if ema:
                    fname += 'ewma' + str(k) + "_"
            fname += str(test_idx.item()) + ".pt"
            
#             print(fpath + fname)
            if os.path.exists(fpath + fname): 
                if model == 'volt':
                    preds = torch.load(fpath + fname)[0]
                elif model == 'matern':
                    preds = torch.load(fpath + fname).cpu()
                else:
                    preds = torch.load(fpath + fname)
                
                preds = preds[:, horizon]
                test_y = torch.tensor(full_data[stn_idx][test_idx:]) + 1
                
#                 return preds, test_y
                if exp:
                    preds = preds.exp()
                pcts = torch.cat((pcts, ECDF(preds, test_y[horizon])))
            
    pcts = pcts.flatten().numpy()
    percentiles = np.linspace(0.05, 0.95, 19)
    for pct in percentiles:
        clb = Calibration(pcts, pct)
        logger.append([clb, np.round(pct, 2), model, theta, ema, k])
        
    return logger

# %%
logger = []
logger = GetCalibration('volt', ema=False, k=200, theta=0.025,
              exp=True, logger=logger)
logger = GetCalibration('lstm', ema=False, theta=0.0,
              exp=True, logger=logger)
logger = GetCalibration('matern', ema=False, theta=0.0,
              exp=True, logger=logger)
logger = GetCalibration('volt', ema=True, k=200, theta=0.025,
              exp=True, logger=logger)
logger = GetCalibration('matern', ema=True, k=200, theta=0.0,
              exp=True, logger=logger)

# %%
df = pd.DataFrame(logger)
df.columns = ['Calibration', 'Percentile', 'Type', 'theta', 'ema', 'k']

# %%
df.to_pickle("wind_calib_df.pkl")

# %% [markdown]
# ## Theta Sensitivity

# %%
logger = []
logger = GetCalibration('volt', theta=0.0,
              exp=True, logger=logger, ema=False)
logger = GetCalibration('volt', theta=0.01,
              exp=True, logger=logger, ema=False)
logger = GetCalibration('volt', theta=0.025,
              exp=True, logger=logger, ema=False)
logger = GetCalibration('volt', theta=0.05,
              exp=True, logger=logger, ema=False)

# %%
df = pd.DataFrame(logger)
df.columns = ['Calibration', 'Percentile', 'Type', 'theta', 'ema', 'k']

# %%
df.to_pickle("theta_calib_df.pkl")

# %% [markdown]
# ## EMA Calibration

# %%
logger = []
logger = GetCalibration('volt', ema=True, theta=0.025, k=50,
              exp=True, logger=logger)
logger = GetCalibration('volt', ema=True, theta=0.025, k=100,
              exp=True, logger=logger)
logger = GetCalibration('volt', ema=True, theta=0.025, k=200,
              exp=True, logger=logger)
logger = GetCalibration('volt', ema=True, theta=0.025, k=400,
              exp=True, logger=logger)
logger = GetCalibration('volt', ema=False, theta=0.025, k=400,
              exp=True, logger=logger)

# %%
df = pd.DataFrame(logger)
df.columns = ['Calibration', 'Percentile', 'Type', 'theta', 'ema', 'k']

# %%
df.to_pickle("./ema_calibration.pkl")

# %% [markdown]
# ## NLL

# %%
def GetNLL(model, ema=True, k=100, theta=0.0, horizon=np.arange(75,100), 
                   logger=[], exp=True):
    
    ntime = full_data[0].shape[0]
    ntrain = 400
    n_test_times = 20
    ntest = 100
    test_idxs = torch.arange(ntrain, ntime-ntest, 
                             int((ntime-ntest-ntrain)/n_test_times))
    
    stns = list(stn_names.keys())
    nlls = torch.tensor([])
    for stn_save_idx, stn_idx in enumerate(stns):
        for test_save_idx, test_idx in enumerate(test_idxs):

            fpath = "./saved-outputs/stn" + str(stn_idx) + "/"
            fname = model + "_"
            if model == 'volt':
                if ema:
                    fname += "ema" + str(k) + "_"
                fname += "theta" + str(theta) + "_"
            if model=='matern':
                if ema:
                    fname += 'ewma' + str(k) + '_'
            if model=='sm':
                if ema:
                    fname += "ewma" + str(k) + "_"
                else:
                    fname += 'constant200' + "_"
            fname += str(test_idx.item()) + ".pt"
            if os.path.exists(fpath + fname): 
                if model == 'volt':
                    preds = torch.load(fpath + fname)[0]
                elif model == 'matern':
                    preds = torch.load(fpath + fname).cpu()
                else:
                    preds = torch.load(fpath + fname)
                
                preds = preds[:, horizon]
                test_y = torch.tensor(full_data[stn_idx][test_idx:]) + 1
                test_y = test_y[horizon]

                if exp:
                    preds = preds.exp()
                
                ## clear out broken data ##
                keepers = torch.where(test_y > 0)[0]
                preds = preds[:, keepers]
                test_y = test_y[keepers]
                
#                 try:
                curr = torch.distributions.Normal(preds.mean(0), preds.std(0)).log_prob(test_y)
                if curr.mean().abs() < 500: ## ignore clearly broken cases
                    nlls = torch.cat((curr, nlls))
#                 except:
#                     pass
            
    if nlls.numel() > 0:
        logger.append([-nlls.sum().item(), -nlls.mean().item(), nlls.std().item(), model, ema, k])
        
    return logger

# %%
logger = []
logger = GetNLL('volt', ema=False, k=200, theta=0.025,
              exp=True, logger=logger)
logger = GetNLL('lstm', theta=0.0,
              exp=True, logger=logger)
logger = GetNLL('matern', theta=0.0, ema=False,
              exp=True, logger=logger)
logger = GetNLL('volt', ema=True, k=200, theta=0.025,
              exp=True, logger=logger)
logger = GetNLL('matern', ema=True, k=200, theta=0.0,
              exp=True, logger=logger)
# Out:
# ./saved-outputs/stn0/volt_theta0.025_400.pt
# ./saved-outputs/stn0/volt_theta0.025_5631.pt
# ./saved-outputs/stn0/volt_theta0.025_10862.pt
# ./saved-outputs/stn0/volt_theta0.025_16093.pt
# ./saved-outputs/stn0/volt_theta0.025_21324.pt
# ./saved-outputs/stn0/volt_theta0.025_26555.pt
# ./saved-outputs/stn0/volt_theta0.025_31786.pt
# ./saved-outputs/stn0/volt_theta0.025_37017.pt
# ./saved-outputs/stn0/volt_theta0.025_42248.pt
# ./saved-outputs/stn0/volt_theta0.025_47479.pt
# ./saved-outputs/stn0/volt_theta0.025_52710.pt
# ./saved-outputs/stn0/volt_theta0.025_57941.pt
# ./saved-outputs/stn0/volt_theta0.025_63172.pt
# ./saved-outputs/stn0/volt_theta0.025_68403.pt
# ./saved-outputs/stn0/volt_theta0.025_73634.pt
# ./saved-outputs/stn0/volt_theta0.025_78865.pt
# ./saved-outputs/stn0/volt_theta0.025_84096.pt
# ./saved-outputs/stn0/volt_theta0.025_89327.pt
# ./saved-outputs/stn0/volt_theta0.025_94558.pt
# ./saved-outputs/stn0/volt_theta0.025_99789.pt
# ./saved-outputs/stn1/volt_theta0.025_400.pt
# ./saved-outputs/stn1/volt_theta0.025_5631.pt
# ./saved-outputs/stn1/volt_theta0.025_10862.pt
# ./saved-outputs/stn1/volt_theta0.025_16093.pt
# ./saved-outputs/stn1/volt_theta0.025_21324.pt
# ./saved-outputs/stn1/volt_theta0.025_26555.pt
# ./saved-outputs/stn1/volt_theta0.025_31786.pt
# ./saved-outputs/stn1/volt_theta0.025_37017.pt
# ./saved-outputs/stn1/volt_theta0.025_42248.pt
# ./saved-outputs/stn1/volt_theta0.025_47479.pt
# ./saved-outputs/stn1/volt_theta0.025_52710.pt
# ./saved-outputs/stn1/volt_theta0.025_57941.pt
# ./saved-outputs/stn1/volt_theta0.025_63172.pt
# ./saved-outputs/stn1/volt_theta0.025_68403.pt
# ./saved-outputs/stn1/volt_theta0.025_73634.pt
# ./saved-outputs/stn1/volt_theta0.025_78865.pt
# ./saved-outputs/stn1/volt_theta0.025_84096.pt
# ./saved-outputs/stn1/volt_theta0.025_89327.pt
# ./saved-outputs/stn1/volt_theta0.025_94558.pt
# ./saved-outputs/stn1/volt_theta0.025_99789.pt
# ./saved-outputs/stn2/volt_theta0.025_400.pt
# ./saved-outputs/stn2/volt_theta0.025_5631.pt
# ./saved-outputs/stn2/volt_theta0.025_10862.pt
# ./saved-outputs/stn2/volt_theta0.025_16093.pt
# ./saved-outputs/stn2/volt_theta0.025_21324.pt
# ./saved-outputs/stn2/volt_theta0.025_26555.pt
# ./saved-outputs/stn2/volt_theta0.025_31786.pt
# ./saved-outputs/stn2/volt_theta0.025_37017.pt
# ./saved-outputs/stn2/volt_theta0.025_42248.pt
# ./saved-outputs/stn2/volt_theta0.025_47479.pt
# ./saved-outputs/stn2/volt_theta0.025_52710.pt
# ./saved-outputs/stn2/volt_theta0.025_57941.pt
# ./saved-outputs/stn2/volt_theta0.025_63172.pt
# ./saved-outputs/stn2/volt_theta0.025_68403.pt
# ./saved-outputs/stn2/volt_theta0.025_73634.pt
# ./saved-outputs/stn2/volt_theta0.025_78865.pt
# ./saved-outputs/stn2/volt_theta0.025_84096.pt
# ./saved-outputs/stn2/volt_theta0.025_89327.pt
# ./saved-outputs/stn2/volt_theta0.025_94558.pt
# ./saved-outputs/stn2/volt_theta0.025_99789.pt
# ./saved-outputs/stn3/volt_theta0.025_400.pt
# ./saved-outputs/stn3/volt_theta0.025_5631.pt
# ./saved-outputs/stn3/volt_theta0.025_10862.pt
# ./saved-outputs/stn3/volt_theta0.025_16093.pt
# ./saved-outputs/stn3/volt_theta0.025_21324.pt
# ./saved-outputs/stn3/volt_theta0.025_26555.pt
# ./saved-outputs/stn3/volt_theta0.025_31786.pt
# ./saved-outputs/stn3/volt_theta0.025_37017.pt
# ./saved-outputs/stn3/volt_theta0.025_42248.pt
# ./saved-outputs/stn3/volt_theta0.025_47479.pt
# ./saved-outputs/stn3/volt_theta0.025_52710.pt
# ./saved-outputs/stn3/volt_theta0.025_57941.pt
# ./saved-outputs/stn3/volt_theta0.025_63172.pt
# ./saved-outputs/stn3/volt_theta0.025_68403.pt
# ./saved-outputs/stn3/volt_theta0.025_73634.pt
# ./saved-outputs/stn3/volt_theta0.025_78865.pt
# ./saved-outputs/stn3/volt_theta0.025_84096.pt
# ./saved-outputs/stn3/volt_theta0.025_89327.pt
# ./saved-outputs/stn3/volt_theta0.025_94558.pt
# ./saved-outputs/stn3/volt_theta0.025_99789.pt
# ./saved-outputs/stn0/lstm_400.pt
# ./saved-outputs/stn0/lstm_5631.pt
# ./saved-outputs/stn0/lstm_10862.pt
# ./saved-outputs/stn0/lstm_16093.pt
# ./saved-outputs/stn0/lstm_21324.pt
# ./saved-outputs/stn0/lstm_26555.pt
# ./saved-outputs/stn0/lstm_31786.pt
# ./saved-outputs/stn0/lstm_37017.pt
# ./saved-outputs/stn0/lstm_42248.pt
# ./saved-outputs/stn0/lstm_47479.pt
# ./saved-outputs/stn0/lstm_52710.pt
# ./saved-outputs/stn0/lstm_57941.pt
# ./saved-outputs/stn0/lstm_63172.pt
# ./saved-outputs/stn0/lstm_68403.pt
# ./saved-outputs/stn0/lstm_73634.pt
# ./saved-outputs/stn0/lstm_78865.pt
# ./saved-outputs/stn0/lstm_84096.pt
# ./saved-outputs/stn0/lstm_89327.pt
# ./saved-outputs/stn0/lstm_94558.pt
# ./saved-outputs/stn0/lstm_99789.pt
# ./saved-outputs/stn1/lstm_400.pt
# ./saved-outputs/stn1/lstm_5631.pt
# ./saved-outputs/stn1/lstm_10862.pt
# ./saved-outputs/stn1/lstm_16093.pt
# ./saved-outputs/stn1/lstm_21324.pt
# ./saved-outputs/stn1/lstm_26555.pt
# ./saved-outputs/stn1/lstm_31786.pt
# ./saved-outputs/stn1/lstm_37017.pt
# ./saved-outputs/stn1/lstm_42248.pt
# ./saved-outputs/stn1/lstm_47479.pt
# ./saved-outputs/stn1/lstm_52710.pt
# ./saved-outputs/stn1/lstm_57941.pt
# ./saved-outputs/stn1/lstm_63172.pt
# ./saved-outputs/stn1/lstm_68403.pt
# ./saved-outputs/stn1/lstm_73634.pt
# ./saved-outputs/stn1/lstm_78865.pt
# ./saved-outputs/stn1/lstm_84096.pt
# ./saved-outputs/stn1/lstm_89327.pt
# ./saved-outputs/stn1/lstm_94558.pt
# ./saved-outputs/stn1/lstm_99789.pt
# ./saved-outputs/stn2/lstm_400.pt
# ./saved-outputs/stn2/lstm_5631.pt
# ./saved-outputs/stn2/lstm_10862.pt
# ./saved-outputs/stn2/lstm_16093.pt
# ./saved-outputs/stn2/lstm_21324.pt
# ./saved-outputs/stn2/lstm_26555.pt
# ./saved-outputs/stn2/lstm_31786.pt
# ./saved-outputs/stn2/lstm_37017.pt
# ./saved-outputs/stn2/lstm_42248.pt
# ./saved-outputs/stn2/lstm_47479.pt
# ./saved-outputs/stn2/lstm_52710.pt
# ./saved-outputs/stn2/lstm_57941.pt
# ./saved-outputs/stn2/lstm_63172.pt
# ./saved-outputs/stn2/lstm_68403.pt
# ./saved-outputs/stn2/lstm_73634.pt
# ./saved-outputs/stn2/lstm_78865.pt
# ./saved-outputs/stn2/lstm_84096.pt
# ./saved-outputs/stn2/lstm_89327.pt
# ./saved-outputs/stn2/lstm_94558.pt
# ./saved-outputs/stn2/lstm_99789.pt
# ./saved-outputs/stn3/lstm_400.pt
# ./saved-outputs/stn3/lstm_5631.pt
# ./saved-outputs/stn3/lstm_10862.pt
# ./saved-outputs/stn3/lstm_16093.pt
# ./saved-outputs/stn3/lstm_21324.pt
# ./saved-outputs/stn3/lstm_26555.pt
# ./saved-outputs/stn3/lstm_31786.pt
# ./saved-outputs/stn3/lstm_37017.pt
# ./saved-outputs/stn3/lstm_42248.pt
# ./saved-outputs/stn3/lstm_47479.pt
# ./saved-outputs/stn3/lstm_52710.pt
# ./saved-outputs/stn3/lstm_57941.pt
# ./saved-outputs/stn3/lstm_63172.pt
# ./saved-outputs/stn3/lstm_68403.pt
# ./saved-outputs/stn3/lstm_73634.pt
# ./saved-outputs/stn3/lstm_78865.pt
# ./saved-outputs/stn3/lstm_84096.pt
# ./saved-outputs/stn3/lstm_89327.pt
# ./saved-outputs/stn3/lstm_94558.pt
# ./saved-outputs/stn3/lstm_99789.pt
# ./saved-outputs/stn0/matern_400.pt
# ./saved-outputs/stn0/matern_5631.pt
# ./saved-outputs/stn0/matern_10862.pt
# ./saved-outputs/stn0/matern_16093.pt
# ./saved-outputs/stn0/matern_21324.pt
# ./saved-outputs/stn0/matern_26555.pt
# ./saved-outputs/stn0/matern_31786.pt
# ./saved-outputs/stn0/matern_37017.pt
# ./saved-outputs/stn0/matern_42248.pt
# ./saved-outputs/stn0/matern_47479.pt
# ./saved-outputs/stn0/matern_52710.pt
# ./saved-outputs/stn0/matern_57941.pt
# ./saved-outputs/stn0/matern_63172.pt
# ./saved-outputs/stn0/matern_68403.pt
# ./saved-outputs/stn0/matern_73634.pt
# ./saved-outputs/stn0/matern_78865.pt
# ./saved-outputs/stn0/matern_84096.pt
# ./saved-outputs/stn0/matern_89327.pt
# ./saved-outputs/stn0/matern_94558.pt
# ./saved-outputs/stn0/matern_99789.pt
# ./saved-outputs/stn1/matern_400.pt
# ./saved-outputs/stn1/matern_5631.pt
# ./saved-outputs/stn1/matern_10862.pt
# ./saved-outputs/stn1/matern_16093.pt
# ./saved-outputs/stn1/matern_21324.pt
# ./saved-outputs/stn1/matern_26555.pt
# ./saved-outputs/stn1/matern_31786.pt
# ./saved-outputs/stn1/matern_37017.pt
# ./saved-outputs/stn1/matern_42248.pt
# ./saved-outputs/stn1/matern_47479.pt
# ./saved-outputs/stn1/matern_52710.pt
# ./saved-outputs/stn1/matern_57941.pt
# ./saved-outputs/stn1/matern_63172.pt
# ./saved-outputs/stn1/matern_68403.pt
# ./saved-outputs/stn1/matern_73634.pt
# ./saved-outputs/stn1/matern_78865.pt
# ./saved-outputs/stn1/matern_84096.pt
# ./saved-outputs/stn1/matern_89327.pt
# ./saved-outputs/stn1/matern_94558.pt
# ./saved-outputs/stn1/matern_99789.pt
# ./saved-outputs/stn2/matern_400.pt
# ./saved-outputs/stn2/matern_5631.pt
# ./saved-outputs/stn2/matern_10862.pt
# ./saved-outputs/stn2/matern_16093.pt
# ./saved-outputs/stn2/matern_21324.pt
# ./saved-outputs/stn2/matern_26555.pt
# ./saved-outputs/stn2/matern_31786.pt
# ./saved-outputs/stn2/matern_37017.pt
# ./saved-outputs/stn2/matern_42248.pt
# ./saved-outputs/stn2/matern_47479.pt
# ./saved-outputs/stn2/matern_52710.pt
# ./saved-outputs/stn2/matern_57941.pt
# ./saved-outputs/stn2/matern_63172.pt
# ./saved-outputs/stn2/matern_68403.pt
# ./saved-outputs/stn2/matern_73634.pt
# ./saved-outputs/stn2/matern_78865.pt
# ./saved-outputs/stn2/matern_84096.pt
# ./saved-outputs/stn2/matern_89327.pt
# ./saved-outputs/stn2/matern_94558.pt
# ./saved-outputs/stn2/matern_99789.pt
# ./saved-outputs/stn3/matern_400.pt
# ./saved-outputs/stn3/matern_5631.pt
# ./saved-outputs/stn3/matern_10862.pt
# ./saved-outputs/stn3/matern_16093.pt
# ./saved-outputs/stn3/matern_21324.pt
# ./saved-outputs/stn3/matern_26555.pt
# ./saved-outputs/stn3/matern_31786.pt
# ./saved-outputs/stn3/matern_37017.pt
# ./saved-outputs/stn3/matern_42248.pt
# ./saved-outputs/stn3/matern_47479.pt
# ./saved-outputs/stn3/matern_52710.pt
# ./saved-outputs/stn3/matern_57941.pt
# ./saved-outputs/stn3/matern_63172.pt
# ./saved-outputs/stn3/matern_68403.pt
# ./saved-outputs/stn3/matern_73634.pt
# ./saved-outputs/stn3/matern_78865.pt
# ./saved-outputs/stn3/matern_84096.pt
# ./saved-outputs/stn3/matern_89327.pt
# ./saved-outputs/stn3/matern_94558.pt
# ./saved-outputs/stn3/matern_99789.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_400.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_5631.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_10862.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_16093.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_21324.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_26555.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_31786.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_37017.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_42248.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_47479.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_52710.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_57941.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_63172.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_68403.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_73634.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_78865.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_84096.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_89327.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_94558.pt
# ./saved-outputs/stn0/volt_ema200_theta0.025_99789.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_400.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_5631.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_10862.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_16093.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_21324.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_26555.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_31786.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_37017.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_42248.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_47479.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_52710.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_57941.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_63172.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_68403.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_73634.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_78865.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_84096.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_89327.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_94558.pt
# ./saved-outputs/stn1/volt_ema200_theta0.025_99789.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_400.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_5631.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_10862.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_16093.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_21324.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_26555.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_31786.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_37017.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_42248.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_47479.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_52710.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_57941.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_63172.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_68403.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_73634.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_78865.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_84096.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_89327.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_94558.pt
# ./saved-outputs/stn2/volt_ema200_theta0.025_99789.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_400.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_5631.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_10862.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_16093.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_21324.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_26555.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_31786.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_37017.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_42248.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_47479.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_52710.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_57941.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_63172.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_68403.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_73634.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_78865.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_84096.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_89327.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_94558.pt
# ./saved-outputs/stn3/volt_ema200_theta0.025_99789.pt
# ./saved-outputs/stn0/matern_ewma200_400.pt
# ./saved-outputs/stn0/matern_ewma200_5631.pt
# ./saved-outputs/stn0/matern_ewma200_10862.pt
# ./saved-outputs/stn0/matern_ewma200_16093.pt
# ./saved-outputs/stn0/matern_ewma200_21324.pt
# ./saved-outputs/stn0/matern_ewma200_26555.pt
# ./saved-outputs/stn0/matern_ewma200_31786.pt
# ./saved-outputs/stn0/matern_ewma200_37017.pt
# ./saved-outputs/stn0/matern_ewma200_42248.pt
# ./saved-outputs/stn0/matern_ewma200_47479.pt
# ./saved-outputs/stn0/matern_ewma200_52710.pt
# ./saved-outputs/stn0/matern_ewma200_57941.pt
# ./saved-outputs/stn0/matern_ewma200_63172.pt
# ./saved-outputs/stn0/matern_ewma200_68403.pt
# ./saved-outputs/stn0/matern_ewma200_73634.pt
# ./saved-outputs/stn0/matern_ewma200_78865.pt
# ./saved-outputs/stn0/matern_ewma200_84096.pt
# ./saved-outputs/stn0/matern_ewma200_89327.pt
# ./saved-outputs/stn0/matern_ewma200_94558.pt
# ./saved-outputs/stn0/matern_ewma200_99789.pt
# ./saved-outputs/stn1/matern_ewma200_400.pt
# ./saved-outputs/stn1/matern_ewma200_5631.pt
# ./saved-outputs/stn1/matern_ewma200_10862.pt
# ./saved-outputs/stn1/matern_ewma200_16093.pt
# ./saved-outputs/stn1/matern_ewma200_21324.pt
# ./saved-outputs/stn1/matern_ewma200_26555.pt
# ./saved-outputs/stn1/matern_ewma200_31786.pt
# ./saved-outputs/stn1/matern_ewma200_37017.pt
# ./saved-outputs/stn1/matern_ewma200_42248.pt
# ./saved-outputs/stn1/matern_ewma200_47479.pt
# ./saved-outputs/stn1/matern_ewma200_52710.pt
# ./saved-outputs/stn1/matern_ewma200_57941.pt
# ./saved-outputs/stn1/matern_ewma200_63172.pt
# ./saved-outputs/stn1/matern_ewma200_68403.pt
# ./saved-outputs/stn1/matern_ewma200_73634.pt
# ./saved-outputs/stn1/matern_ewma200_78865.pt
# ./saved-outputs/stn1/matern_ewma200_84096.pt
# ./saved-outputs/stn1/matern_ewma200_89327.pt
# ./saved-outputs/stn1/matern_ewma200_94558.pt
# ./saved-outputs/stn1/matern_ewma200_99789.pt
# ./saved-outputs/stn2/matern_ewma200_400.pt
# ./saved-outputs/stn2/matern_ewma200_5631.pt
# ./saved-outputs/stn2/matern_ewma200_10862.pt
# ./saved-outputs/stn2/matern_ewma200_16093.pt
# ./saved-outputs/stn2/matern_ewma200_21324.pt
# ./saved-outputs/stn2/matern_ewma200_26555.pt
# ./saved-outputs/stn2/matern_ewma200_31786.pt
# ./saved-outputs/stn2/matern_ewma200_37017.pt
# ./saved-outputs/stn2/matern_ewma200_42248.pt
# ./saved-outputs/stn2/matern_ewma200_47479.pt
# ./saved-outputs/stn2/matern_ewma200_52710.pt
# ./saved-outputs/stn2/matern_ewma200_57941.pt
# ./saved-outputs/stn2/matern_ewma200_63172.pt
# ./saved-outputs/stn2/matern_ewma200_68403.pt
# ./saved-outputs/stn2/matern_ewma200_73634.pt
# ./saved-outputs/stn2/matern_ewma200_78865.pt
# ./saved-outputs/stn2/matern_ewma200_84096.pt
# ./saved-outputs/stn2/matern_ewma200_89327.pt
# ./saved-outputs/stn2/matern_ewma200_94558.pt
# ./saved-outputs/stn2/matern_ewma200_99789.pt
# ./saved-outputs/stn3/matern_ewma200_400.pt
# ./saved-outputs/stn3/matern_ewma200_5631.pt
# ./saved-outputs/stn3/matern_ewma200_10862.pt
# ./saved-outputs/stn3/matern_ewma200_16093.pt
# ./saved-outputs/stn3/matern_ewma200_21324.pt
# ./saved-outputs/stn3/matern_ewma200_26555.pt
# ./saved-outputs/stn3/matern_ewma200_31786.pt
# ./saved-outputs/stn3/matern_ewma200_37017.pt
# ./saved-outputs/stn3/matern_ewma200_42248.pt
# ./saved-outputs/stn3/matern_ewma200_47479.pt
# ./saved-outputs/stn3/matern_ewma200_52710.pt
# ./saved-outputs/stn3/matern_ewma200_57941.pt
# ./saved-outputs/stn3/matern_ewma200_63172.pt
# ./saved-outputs/stn3/matern_ewma200_68403.pt
# ./saved-outputs/stn3/matern_ewma200_73634.pt
# ./saved-outputs/stn3/matern_ewma200_78865.pt
# ./saved-outputs/stn3/matern_ewma200_84096.pt
# ./saved-outputs/stn3/matern_ewma200_89327.pt
# ./saved-outputs/stn3/matern_ewma200_94558.pt
# ./saved-outputs/stn3/matern_ewma200_99789.pt

# %%
# logger = GetNLL('matern', theta=0.0, ema=False,
#               exp=True, logger=[])

logger = GetNLL('sm', theta=0.0, ema=True,
              exp=True, logger=[], k=200)
logger = GetNLL('sm', theta=0.0, ema=False,
              exp=True, logger=logger, k=200)

# %%
df = pd.DataFrame(logger)
df.columns = ["NLL", "Mean_NLL", "Std_NLL", "kernel", "ema", "k"]

# %%
df
# Out:
#             NLL    Mean_NLL     Std_NLL kernel    ema    k
# 0  2.532691e+06  110.069138  163.039618     sm   True  200
# 1  1.899801e+06   70.144774  134.305314     sm  False  200
